# %% [markdown]
# ## **haarcascade**

# %%
# !pip install face_recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=0f2da7fe0623bda30b99d4c40b92447aa680bd27aff1d30d40ca86813343a007
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
# !pip install face_recognition
# !pip install cmake==3.14.4
# !pip install scikit-learn==0.21.2
# !pip install opencv-python
# !pip install python==3.6
# # !pip install dlib==3.6
# # !pip install dlib-19.8.1-cp36-cp36m-win_amd64.whl

# %%
# import cv2

# # image source : https://unsplash.com/ko/%EC%82%AC%EC%A7%84/hOF1bWoet_Q
# image = cv2.imread('/content/drive/MyDrive/images/people.png')
# image2 = cv2.imread('/content/drive/MyDrive/images/demo1.jpg')
# image3 = cv2.imread('/content/drive/MyDrive/images/demo3.jpg')
# image4 = cv2.imread('/content/drive/MyDrive/images/demo4.jpg')

# %%
# from google.colab.patches import cv2_imshow

# cv2_imshow(image)

# %%
# image_resized = cv2.resize(image, (755, 500))

# %%
# # Load prebuilt cascade classifier for detecting fontalfaces
# cascade_face_detector = cv2.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_default.xml')

# %%
# face_detections = cascade_face_detector.detectMultiScale(image_resized)

# %%
# image_resized = cv2.resize(image, (755, 500))

# face_detections = cascade_face_detector.detectMultiScale(image_resized, scaleFactor=1.1, minNeighbors=4)

# for (x, y, w, h) in face_detections:
#     cv2.rectangle(image_resized, (x, y), (x + w, y + h), (0, 255, 0), 2)

# cv2_imshow(image_resized)

# %%
# # Load prebuilt cascade classifier for detecting fontalfaces
# cascade_profileface_detector = cv2.CascadeClassifier('/content/drive/MyDrive/haarcascade_profileface.xml')

# %%
# image2_resized = cv2.resize(image2, (755, 500))

# face_detections = cascade_face_detector.detectMultiScale(image2_resized, scaleFactor=1.1, minNeighbors=4)

# for (x, y, w, h) in face_detections:
#     cv2.rectangle(image2_resized, (x, y), (x + w, y + h), (0, 255, 0), 2)

# cv2_imshow(image2_resized)

# %%
# image3_resized = cv2.resize(image3, (755, 500))

# face_detections = cascade_face_detector.detectMultiScale(image3_resized, scaleFactor=1.1, minNeighbors=4)

# for (x, y, w, h) in face_detections:
#     cv2.rectangle(image3_resized, (x, y), (x + w, y + h), (0, 255, 0), 2)

# cv2_imshow(image3_resized)

# %%
# image4_resized = cv2.resize(image4, (755, 500))

# face_detections = cascade_face_detector.detectMultiScale(image4_resized, scaleFactor=1.1, minNeighbors=4)

# for (x, y, w, h) in face_detections:
#     cv2.rectangle(image4_resized, (x, y), (x + w, y + h), (0, 255, 0), 2)

# cv2_imshow(image4_resized)

# %% [markdown]
# ## **face_recognition**

# %%
import os
import face_recognition as fr
from IPython.display import Image, display
from PIL import Image, ImageDraw
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
from google.colab import drive
drive.mount('/gdrive')

with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'
# Out:
# Mounted at /gdrive
# Hello Google Drive!

# %%
from PIL import Image
import face_recognition

# 절대 경로를 사용하여 이미지 파일 경로 지정
image_path = '/gdrive/MyDrive/images/demo4.jpg'

try:
    # 이미지 파일 열기
    image2 = Image.open(image_path)
except Exception as e:
    print(f"이미지를 열 때 오류가 발생했습니다: {e}")
    # 에러 처리: 예를 들어 올바른 이미지 경로를 제공하거나 스크립트를 중단합니다.

# PIL 이미지를 NumPy 배열로 변환 (dtype='uint8'로 명시적으로 지정)
image_array = np.array(image2, dtype='uint8')

# 얼굴 특징점 감지 수행
face_landmarks_list = face_recognition.face_landmarks(image_array)

print("이 사진에서 {}개의 얼굴을 찾았습니다.".format(len(face_landmarks_list)))
# Out:
# 이 사진에서 1개의 얼굴을 찾았습니다.

# %%
face_locations = face_recognition.face_locations(image_array)

# %%
for(top, right, bottom, left) in face_locations:
  cv2.rectangle(image_array, (left, top), (right, bottom), (0,255,0),3)

# %%
# 이미지 버퍼 출력
plt.rcParams["figure.figsize"]=(16, 16)
plt.imshow(image_array)
plt.show()

# %%
# # 동일 인물 인식하기

# plt.rcParams["figure.figsize"] = (1,1)



# # 이미지 파일 로드하여 known_person_list 생성
# known_person_list = []
# known_person_list.append(face_recognition.load_image_file("/gdrive/MyDrive/images/demo2.jpg"))
# known_person_list.append(face_recognition.load_image_file("/gdrive/MyDrive/images/demo4.jpg"))

# %%
# # 얼굴을 인식하여 감지된 부분을 잘라낸 다음 known_face_list에 저장
# known_face_list = []
# for person in known_person_list:
#   # 얼굴 좌표 알아내서 잘라내기
#   top, right, bottom, left = face_recognition.face_locations(person)[0]
#   face_image = person[top:bottom, left:right]

#   # known_face_list에 잘라낸 face_image 저장
#   known_face_list.append(face_image)

# %%
# # known_face_list에 저장된 얼굴들 출력
# for face in known_face_list:
#   plt.imshow(face)
#   plt.show()

# %%
# # 기존 리스트에 없는 새로운 파일을 열어서
# unknown_person = face_recognition.load_image_file("/gdrive/MyDrive/images/demo3.jpg")

# # 얼굴 좌표를 알아내서 잘라내기
# top, right, bottom, left = face_recognition.face_locations(unknown_person)[0]
# unknown_face = np.array(unknown_person[top:bottom, left:right])

# %%
# # unknown_face라는 타이틀 붙여서 표시
# plt.title("unknown_face")
# plt.imshow(unknown_face)
# plt.show()

# %%
# # unknown_person_face를 인코딩
# print(type(unknown_face))
# enc_unknown_face = face_recognition.face_encodings(unknown_face)

# # 화면에 표시해보기
# plt.imshow(enc_unknown_face)
# plt.show()

# %%
# known_person_list = []
# known_person_list.append(face_recognition.load_image_file("/gdrive/MyDrive/images/demo2.jpg"))
# known_person_list.append(face_recognition.load_image_file("/gdrive/MyDrive/images/demo4.jpg"))
# known_person_list.append(face_recognition.load_image_file("/gdrive/MyDrive/images/demo3.jpg"))

# # 얼굴을 인식하여 감지된 부분을 잘라낸 다음 known_face_list에 저장
# known_face_list = []
# for person in known_person_list:
#   # 얼굴 좌표 알아내서 잘라내기
#   top, right, bottom, left = face_recognition.face_locations(person)[0]
#   face_image = person[top:bottom, left:right]

#   # known_face_list에 잘라낸 face_image 저장
#   known_face_list.append(face_image)



# # 등록된 얼굴리스트 비교
# for face in known_face_list:
#   # 등록된 얼굴을 128-dimensional face 인코딩
#   face = np.array(face)
#   enc_known_face = face_recognition.face_encodings(face)

#   # 등록된 얼굴과 새로운 얼굴의 distance 얻기
#   distance = face_recognition.face_distance(enc_known_face, enc_unknown_face[0])

#   # distance 수치를 포함한 얼굴 출력
#   plt.title("distance: " + str(distance))
#   plt.imshow(face)
#   plt.show()

#   # 결과 출력
#   if distance >= 0.6: print("다른 사람입니다.")
#   else: print("유사합니다.")
#   print()

# %% [markdown]
# ## **face_recognition + knn**

# %%
import os
import face_recognition
from IPython.display import Image, display
from PIL import Image, ImageDraw
from matplotlib import pyplot as plt
import numpy as np

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
pil_image = Image.fromarray(image_array)

for face_landmarks in face_landmarks_list:
    draw = ImageDraw.Draw(pil_image, 'RGBA')

    # Make the eyebrows into a nightmare
    draw.polygon(face_landmarks['left_eyebrow'], fill=(68, 54, 39, 128))
    draw.polygon(face_landmarks['right_eyebrow'], fill=(68, 54, 39, 128))
    draw.line(face_landmarks['left_eyebrow'], fill=(68, 54, 39, 150), width=5)
    draw.line(face_landmarks['right_eyebrow'], fill=(68, 54, 39, 150), width=5)

    # Gloss the lips
    draw.polygon(face_landmarks['top_lip'], fill=(150, 0, 0, 128))
    draw.polygon(face_landmarks['bottom_lip'], fill=(150, 0, 0, 128))
    draw.line(face_landmarks['top_lip'], fill=(150, 0, 0, 64), width=8)
    draw.line(face_landmarks['bottom_lip'], fill=(150, 0, 0, 64), width=8)

    # Sparkle the eyes
    draw.polygon(face_landmarks['left_eye'], fill=(255, 255, 255, 30))
    draw.polygon(face_landmarks['right_eye'], fill=(255, 255, 255, 30))

    # Apply some eyeliner
    draw.line(face_landmarks['left_eye'] + [face_landmarks['left_eye'][0]], fill=(0, 0, 0, 110), width=6)
    draw.line(face_landmarks['right_eye'] + [face_landmarks['right_eye'][0]], fill=(0, 0, 0, 110), width=6)

    pil_image.show()

# %%
import math
from sklearn import neighbors
import os
import os.path
import pickle
from PIL import Image, ImageDraw
import face_recognition
from face_recognition.face_recognition_cli import image_files_in_folder

ALLOWED_EXTENSIONS = {'png', 'jpg', 'jpeg'}


def train(train_dir, model_save_path=None, n_neighbors=None, knn_algo='ball_tree', verbose=False):
    """
    Trains a k-nearest neighbors classifier for face recognition.

    :param train_dir: directory that contains a sub-directory for each known person, with its name.

     (View in source code to see train_dir example tree structure)

     Structure:
        <train_dir>/
        ├── <idol_name1>/
        │   ├── <filename1>.jpg
        │   ├── <filename2>.jpg
        │   ├── ...
        ├── <idol_name2>/
        │   ├── <filename1>.jpg
        │   └── <filename2>.jpg
        └── ...

    :param model_save_path: (optional) path to save model on disk
    :param n_neighbors: (optional) number of neighbors to weigh in classification. Chosen automatically if not specified
    :param knn_algo: (optional) underlying data structure to support knn.default is ball_tree
    :param verbose: verbosity of training
    :return: returns knn classifier that was trained on the given data.
    """
    X = []
    y = []

    # Loop through each person in the training set
    for class_dir in os.listdir(train_dir):
        if not os.path.isdir(os.path.join(train_dir, class_dir)):
            continue

        # Loop through each training image for the current person
        for img_path in image_files_in_folder(os.path.join(train_dir, class_dir)):
            image = face_recognition.load_image_file(img_path)
            face_bounding_boxes = face_recognition.face_locations(image)

            if len(face_bounding_boxes) != 1:
                # If there are no people (or too many people) in a training image, skip the image.
                if verbose:
                    print("Image {} not suitable for training: {}".format(img_path, "Didn't find a face" if len(face_bounding_boxes) < 1 else "Found more than one face"))
            else:
                # Add face encoding for current image to the training set
                X.append(face_recognition.face_encodings(image, known_face_locations=face_bounding_boxes)[0])
                y.append(class_dir)

    # Determine how many neighbors to use for weighting in the KNN classifier
    if n_neighbors is None:
        n_neighbors = int(round(math.sqrt(len(X))))
        if verbose:
            print("Chose n_neighbors automatically:", n_neighbors)

    # Create and train the KNN classifier
    knn_clf = neighbors.KNeighborsClassifier(n_neighbors=n_neighbors, algorithm=knn_algo, weights='distance')
    knn_clf.fit(X, y)

    # Save the trained KNN classifier
    if model_save_path is not None:
        with open(model_save_path, 'wb') as f:
            pickle.dump(knn_clf, f)

    return knn_clf


def predict(X_img_path, knn_clf=None, model_path=None, distance_threshold=0.6):
    if not os.path.isfile(X_img_path) or os.path.splitext(X_img_path)[1][1:] not in ALLOWED_EXTENSIONS:
        raise Exception("Invalid image path: {}".format(X_img_path))

    if knn_clf is None and model_path is None:
        raise Exception("Must supply knn classifier either thourgh knn_clf or model_path")

    # Load a trained KNN model (if one was passed in)
    if knn_clf is None:
        with open(model_path, 'rb') as f:
            knn_clf = pickle.load(f)

    # Load image file and find face locations
    X_img = face_recognition.load_image_file(X_img_path)
    X_face_locations = face_recognition.face_locations(X_img)

    # If no faces are found in the image, return an empty result.
    if len(X_face_locations) == 0:
        return []

    # Find encodings for faces in the test iamge
    faces_encodings = face_recognition.face_encodings(X_img, known_face_locations=X_face_locations)

    # Use the KNN model to find the best matches for the test face
    closest_distances = knn_clf.kneighbors(faces_encodings, n_neighbors=1)
    are_matches = [closest_distances[0][i][0] <= distance_threshold for i in range(len(X_face_locations))]

    # Predict classes and remove classifications that aren't within the threshold
    return [(pred, loc) if rec else ("unknown", loc) for pred, loc, rec in zip(knn_clf.predict(faces_encodings), X_face_locations, are_matches)]


def show_prediction_labels_on_image(img_path, predictions):
    """
    Shows the face recognition results visually.

    :param img_path: path to image to be recognized
    :param predictions: results of the predict function
    :return:
    """
    pil_image = Image.open(img_path).convert("RGB")
    draw = ImageDraw.Draw(pil_image)

    for name, (top, right, bottom, left) in predictions:
        # Draw a box around the face using the Pillow module
        draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 255))

        # There's a bug in Pillow where it blows up with non-UTF-8 text
        # when using the default bitmap font
        name = name.encode("UTF-8")

        # Draw a label with a name below the face
        text_width, text_height = draw.textsize(name)
        draw.rectangle(((left, bottom - text_height - 10), (right, bottom)), fill=(0, 0, 255), outline=(0, 0, 255))
        draw.text((left + 6, bottom - text_height - 5), name, fill=(255, 255, 255, 255))

    # Remove the drawing library from memory as per the Pillow docs
    del draw

    # Display the resulting image
    pil_image.show()


if __name__ == "__main__":

    # Update the train_dir path
    train_dir = '/content/drive/MyDrive/images/new_jeans_img/train_dir/'

    # STEP 1: Train the KNN classifier and save it to disk
    print("Training KNN classifier...")
    classifier = train(train_dir, model_save_path="/content/drive/MyDrive/trained_knn_model.clf", n_neighbors=2)
    print("Training complete!")

    # STEP 2: Using the trained classifier, make predictions for unknown images
    test_dir = '/content/drive/MyDrive/images/new_jeans_img/test_dir/'

    # Iterate through subdirectories (each subdirectory corresponds to a person)
    for person_dir in os.listdir(test_dir):
        person_path = os.path.join(test_dir, person_dir)

        # Check if the item in test_dir is a directory
        if os.path.isdir(person_path):
            # Iterate through image files in the person's directory
            for image_file in os.listdir(person_path):
                full_file_path = os.path.join(person_path, image_file)

                print(f"Looking for faces in {image_file} for {person_dir}")

                # Find all people in the image using a trained classifier model
                # Note: You can pass in either a classifier file name or a classifier model instance
                predictions = predict(full_file_path, model_path="/content/drive/MyDrive/trained_knn_model.clf")

                # Print results on the console
                for name, (top, right, bottom, left) in predictions:
                    print(f"- Found {name} at ({left}, {top}) for {person_dir}")

                # Display results overlaid on an image
                show_prediction_labels_on_image(full_file_path, predictions)
# Out:
# Training KNN classifier...
# Training complete!
# Looking for faces in 52.jpeg for daniel
# Looking for faces in 53.jpg for daniel
# - Found daniel at (0, 172) for daniel
# <ipython-input-29-986c834baaf0>:129: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(name)
# Looking for faces in 54.jpg for daniel
# - Found daniel at (134, 241) for daniel
# <ipython-input-29-986c834baaf0>:129: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(name)
# Looking for faces in 55.jpg for daniel
# - Found daniel at (98, 170) for daniel
# <ipython-input-29-986c834baaf0>:129: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(name)
# ...

# %%
# Update the test image path
test_image_path = '/content/drive/MyDrive/images/nj5.png'

# Using the trained classifier, make predictions for the test image
predictions = predict(test_image_path, model_path="/content/drive/MyDrive/trained_knn_model.clf")

# Print results on the console
for name, (top, right, bottom, left) in predictions:
    print(f"- Found {name} at ({left}, {top})")

# Display results overlaid on the test image
show_prediction_labels_on_image(test_image_path, predictions)
# Out:
# - Found daniel at (285, 106)
# - Found haerin at (384, 66)
# - Found hyein at (185, 66)
# - Found minji at (514, 66)
# - Found hani at (96, 96)
# <ipython-input-29-986c834baaf0>:129: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(name)
# <ipython-input-29-986c834baaf0>:129: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(name)
# <ipython-input-29-986c834baaf0>:129: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(name)
# <ipython-input-29-986c834baaf0>:129: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
# ...

# %%
from sklearn.metrics import accuracy_score

# Update the test_dir path
test_dir = '/content/drive/MyDrive/images/new_jeans_img/test_dir/'

# Lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through subdirectories (each subdirectory corresponds to a person)
for person_dir in os.listdir(test_dir):
    person_path = os.path.join(test_dir, person_dir)

    # Check if the item in test_dir is a directory
    if os.path.isdir(person_path):
        # Iterate through image files in the person's directory
        for image_file in os.listdir(person_path):
            full_file_path = os.path.join(person_path, image_file)

            # Extract the true label from the directory name
            true_label = person_dir

            # Find all people in the image using a trained classifier model
            # Note: You can pass in either a classifier file name or a classifier model instance
            predictions = predict(full_file_path, model_path="/content/drive/MyDrive/Openvino_SmartGalleryTeamProject/trained_knn_model.clf")

            # Extract the predicted label
            if predictions:
                predicted_label = predictions[0][0]
            else:
                predicted_label = "unknown"

            # Store true and predicted labels
            true_labels.append(true_label)
            predicted_labels.append(predicted_label)

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.93

# %%
# !pip install seaborn matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Calculate confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=sorted(set(true_labels)),
            yticklabels=sorted(set(true_labels)))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Display classification report
report = classification_report(true_labels, predicted_labels)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       daniel       1.00      0.95      0.97        20
#       haerin       1.00      0.80      0.89        20
#         hani       0.95      1.00      0.98        20
#        hyein       0.95      0.95      0.95        20
#        minji       1.00      0.95      0.97        20
#      unknown       0.00      0.00      0.00         0
#
#     accuracy                           0.93       100
#    macro avg       0.82      0.78      0.79       100
# weighted avg       0.98      0.93      0.95       100
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # **face_recognition + encoding**

# %%
# import cv2
# import face_recognition
# import os

# knownEncodings = []
# knownNames = []

# # 이미지 파일이 있는 폴더 경로
# image_folder = '/content/drive/MyDrive/images/new_jeans_img/train_dir/'

# # 폴더 내의 각 파일에 대해
# for person_dir in os.listdir(image_folder):
#     person_path = os.path.join(image_folder, person_dir)

#     # 폴더인 경우에만 진행
#     if os.path.isdir(person_path):
#         # 각 폴더 내의 이미지 파일에 대해
#         for image_file in os.listdir(person_path):
#             # 이미지 파일의 전체 경로를 생성
#             full_file_path = os.path.join(person_path, image_file)

#             # 이미지 파일을 읽어옴
#             image = cv2.imread(full_file_path)

#             # 얼굴 위치 찾기
#             boxes = face_recognition.face_locations(image)
#             encodings = face_recognition.face_encodings(image, boxes)

#             # 결과 확인
#             print(f"Number of faces detected in {image_file}: {len(boxes)}")

#             # 각 얼굴에 대해 인코딩 및 이름 저장
#             for encoding in encodings:
#                 knownEncodings.append(encoding)
#                 knownNames.append(person_dir)

# # 결과 확인
# print("Known Encodings:")
# print(knownEncodings)
# print("Known Names:")
# print(knownNames)

# %%
# import pickle

# data = {"encodings": knownEncodings, "names": knownNames}

# # Specify the file path within the train_dir directory
# file_path = '/content/drive/MyDrive/images/new_jeans_img/train_dir/encodings.pkl'

# # Open the file in binary write mode and write the data
# with open(file_path, "wb") as f:
#     pickle.dump(data, f)

# print(f"Encodings and names saved to {file_path}")

# %%
# # Load the image
# imgs = cv2.imread('/content/drive/MyDrive/images/nj5.png')

# boxes = face_recognition.face_locations(imgs)
# encodings = face_recognition.face_encodings(imgs, boxes)

# names = []
# for encoding in encodings:
#   matches = face_recognition.compare_faces(data["encodings"], encoding)
#   name = "Unknown"

#   if True in matches:
#     matchedIdxs = [i for (i, b) in enumerate(matches) if b]
#     counts = {}

#     for i in matchedIdxs:
#       name = data["names"][i]
#       counts[name] = counts.get(name, 0)+1
#     name = max(counts, key = counts.get)
#   names.append(name)

# for ((top, right, bottom, left), name) in zip(boxes, names):
#   cv2.rectangle(imgs,(left, top), (right, bottom), (0,255,0), 2)
#   y=top-15 if top-15> 15 else top + 15
#   cv2.putText(imgs, name, (left, y), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,255,0), 2)

# # Set the size of the displayed image
# plt.figure(figsize=(8, 8))

# # Display the image
# plt.imshow(cv2.cvtColor(imgs, cv2.COLOR_BGR2RGB))
# plt.show()

# %% [markdown]
# ## **CNN**

# %%
# import os
# import cv2
# import numpy as np
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder
# from tensorflow.keras.utils import to_categorical

# def load_images_from_folder(folder, target_size=(128, 128)):
#     images = []
#     labels = []
#     for person in os.listdir(folder):
#         person_folder = os.path.join(folder, person)
#         if os.path.isdir(person_folder):
#             for filename in os.listdir(person_folder):
#                 img_path = os.path.join(person_folder, filename)
#                 img = cv2.imread(img_path)
#                 if img is not None:
#                     # Resize the image to the target size
#                     img = cv2.resize(img, target_size)
#                     images.append(img)
#                     labels.append(person)
#     return np.array(images, dtype=object), np.array(labels, dtype=object)

# %%
# # 데이터 로드 및 전처리
# train_dir = '/content/drive/MyDrive/images/new_jeans_img/train_dir/'
# test_dir = '/content/drive/MyDrive/images/new_jeans_img/test_dir/'

# target_size = (128, 128)

# X_train, y_train = load_images_from_folder(train_dir, target_size=target_size)
# X_test, y_test = load_images_from_folder(test_dir, target_size=target_size)

# %%
# # Label Encoding
# le = LabelEncoder()
# y_train_encoded = le.fit_transform(y_train)
# y_test_encoded = le.transform(y_test)

# %%
# # Convert integer labels to one-hot encoded format
# y_train_one_hot = to_categorical(y_train_encoded)
# y_test_one_hot = to_categorical(y_test_encoded)

# %%
# # 모델 훈련을 위한 전처리
# X_train = X_train.astype('float32') / 255.0
# X_test = X_test.astype('float32') / 255.0

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# # CNN 모델 정의
# model = Sequential()
# model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
# model.add(MaxPooling2D((2, 2)))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(MaxPooling2D((2, 2)))
# model.add(Flatten())
# model.add(Dense(64, activation='relu'))
# model.add(Dense(5, activation='softmax'))
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# # 모델 훈련
# model.fit(X_train, y_train_one_hot, epochs=10, validation_split=0.2)

# %%
# # 모델 평가
# y_pred = model.predict(X_test)
# y_pred_classes = np.argmax(y_pred, axis=1)
# accuracy = accuracy_score(y_test_encoded, y_pred_classes)
# print("Accuracy:", accuracy)

# %% [markdown]
# # **MTCNN + OpenCV**

# %%
# import cv2
# from mtcnn.mtcnn import MTCNN
# from matplotlib import pyplot as plt

# # 이미지 로드
# image_path = '/content/drive/MyDrive/images/nj5.png'
# image = cv2.imread(image_path)
# image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# # MTCNN 모델 로드
# mtcnn = MTCNN()

# # 얼굴 감지
# faces = mtcnn.detect_faces(image_rgb)

# # 각 얼굴에 레이블 붙이기
# for i, face_info in enumerate(faces):
#     x, y, w, h = face_info['box']
#     label = f"Face {i+1}"
#     cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
#     cv2.putText(image, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# # 결과 이미지 출력
# plt.imshow(image)
# plt.axis('off')
# plt.show()

# %%
# import cv2
# from mtcnn.mtcnn import MTCNN
# from matplotlib import pyplot as plt
# import os

# # 이미지 로드
# image_path = '/content/drive/MyDrive/images/nj6.png'
# image = cv2.imread(image_path)
# image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# # MTCNN 모델 로드
# mtcnn = MTCNN()

# # 얼굴 감지
# faces = mtcnn.detect_faces(image_rgb)

# # 클래스 레이블 가져오기
# base_dir = '/content/drive/MyDrive/images/new_jeans_img/'
# train_dir = os.path.join(base_dir, 'train_dir')
# test_dir = os.path.join(base_dir, 'test_dir')
# class_labels = os.listdir(train_dir)

# # 각 얼굴에 대해 각각의 레이블 표시
# for face_info in faces:
#     x, y, w, h = face_info['box']

#     # 얼굴의 중심 좌표 구하기
#     center_x = x + w // 2
#     center_y = y + h // 2

#     # 얼굴이 속한 클래스(레이블) 찾기
#     labels_found = []
#     for label in class_labels:
#         label_dir = os.path.join(train_dir, label)
#         image_files = os.listdir(label_dir)
#         for image_file in image_files:
#             image_path = os.path.join(label_dir, image_file)
#             image_info = cv2.imread(image_path)
#             image_height, image_width, _ = image_info.shape

#             # 얼굴이 속한 클래스의 이미지 안에 있으면 레이블 추가
#             if 0 < center_x < image_width and 0 < center_y < image_height:
#                 labels_found.append(label)
#                 break

#     # 얼굴에 대한 박스와 레이블 표시
#     if labels_found:
#         label_text = ', '.join(labels_found)
#         cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
#         cv2.putText(image, label_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# # 결과 이미지 출력
# plt.imshow(image)
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## **MobileNetV2 + FaceNet**

# %%
# !pip install facenet

# %%
# import numpy as np
# import tensorflow as tf
# from tensorflow.keras import layers, models
# from sklearn.preprocessing import LabelEncoder
# from sklearn.model_selection import train_test_split
# from sklearn.utils import shuffle
# import os
# import cv2

# # 데이터 경로 설정
# base_dir = '/content/drive/MyDrive/images/new_jeans_img/'
# train_dir = os.path.join(base_dir, 'train_dir')
# test_dir = os.path.join(base_dir, 'test_dir')

# # 클래스 레이블 가져오기
# class_labels = os.listdir(train_dir)

# # 이미지 데이터 및 레이블 로드
# data = []
# labels = []

# for label in class_labels:
#     label_dir = os.path.join(train_dir, label)
#     for image_file in os.listdir(label_dir):
#         image_path = os.path.join(label_dir, image_file)
#         image = cv2.imread(image_path)
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         data.append(image)
#         labels.append(label)

# # 데이터를 NumPy 배열로 변환
# data = np.array(data)
# labels = np.array(labels)

# # 클래스 레이블 인코딩
# le = LabelEncoder()
# labels_encoded = le.fit_transform(labels)

# # 데이터 섞기
# data_shuffled, labels_shuffled = shuffle(data, labels_encoded, random_state=42)

# # 훈련 데이터와 검증 데이터로 분할
# train_data, val_data, train_labels, val_labels = train_test_split(data_shuffled, labels_shuffled, test_size=0.2, random_state=42)

# # MobileNetV2 모델 생성
# mobilenet_model = tf.keras.applications.MobileNetV2(input_shape=(160, 160, 3), include_top=False, weights='imagenet')
# mobilenet_model.trainable = False

# # FaceNet 모델 생성
# facenet_model = tf.keras.applications.InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(160, 160, 3))
# facenet_model.trainable = False

# # Resize MobileNetV2 output to match the input shape of FaceNet
# resized_mobilenet_output = tf.image.resize(mobilenet_model.output, (5, 5))  # Adjusted resizing

# # 모델 결합
# combined_input = tf.keras.Input(shape=(160, 160, 3))
# mobilenet_output = mobilenet_model(combined_input)
# facenet_output = facenet_model(resized_mobilenet_output)
# flatten_output = layers.Flatten()(facenet_output)  # Flatten instead of GlobalAveragePooling2D
# output = layers.Dense(len(class_labels), activation='softmax')(flatten_output)

# combined_model = models.Model(inputs=combined_input, outputs=output)

# # 모델 컴파일 및 훈련
# combined_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# combined_model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=10)

# %% [markdown]
# ## **Blazeface**

# %%
# !pip install blazeface
# !pip install tensorflow-addons

# %%
# import cv2
# from blazeface import BlazeFace
# from sklearn.preprocessing import LabelEncoder
# from sklearn.model_selection import train_test_split
# from sklearn.utils import shuffle
# import os

# # Load BlazeFace model
# blazeface = BlazeFace()

# # 데이터 경로 설정
# base_dir = '/content/drive/MyDrive/images/new_jeans_img/'
# train_dir = os.path.join(base_dir, 'train_dir')
# test_dir = os.path.join(base_dir, 'test_dir')

# # 클래스 레이블 가져오기
# class_labels = os.listdir(train_dir)

# # 이미지 데이터 및 레이블 로드
# data = []
# labels = []

# for label in class_labels:
#     label_dir = os.path.join(train_dir, label)
#     for image_file in os.listdir(label_dir):
#         image_path = os.path.join(label_dir, image_file)
#         image = cv2.imread(image_path)
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         data.append(image)
#         labels.append(label)

# # 데이터를 NumPy 배열로 변환
# data = np.array(data)
# labels = np.array(labels)

# # 클래스 레이블 인코딩
# le = LabelEncoder()
# labels_encoded = le.fit_transform(labels)

# # 데이터 섞기
# data_shuffled, labels_shuffled = shuffle(data, labels_encoded, random_state=42)

# # 훈련 데이터와 검증 데이터로 분할
# train_data, val_data, train_labels, val_labels = train_test_split(data_shuffled, labels_shuffled, test_size=0.2, random_state=42)

# # 얼굴 감지 및 레이블링
# for i in range(len(val_data)):
#     image = val_data[i]
#     label = class_labels[val_labels[i]]

#     # BlazeFace를 사용하여 얼굴 감지
#     faces = blazeface.predict_on_image(image)

#     # 얼굴에 레이블 붙이기
#     for face in faces:
#         x, y, w, h = face
#         cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
#         cv2.putText(image, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

#     # 결과 이미지 출력
#     cv2.imshow('Result', image)
#     cv2.waitKey(0)

# cv2.destroyAllWindows()

# %% [markdown]
# ## **DeepFace**

# %%
# !pip install deepface

# %%
# from deepface import DeepFace
# import cv2
# from sklearn.preprocessing import LabelEncoder
# from sklearn.model_selection import train_test_split
# from sklearn.utils import shuffle
# import os
# from IPython.display import Image, display

# # 데이터 경로 설정
# base_dir = '/content/drive/MyDrive/images/new_jeans_img/'
# train_dir = os.path.join(base_dir, 'train_dir')
# test_dir = os.path.join(base_dir, 'test_dir')

# # 클래스 레이블 가져오기
# class_labels = os.listdir(train_dir)

# # 이미지 데이터 및 레이블 로드
# data = []
# labels = []

# for label in class_labels:
#     label_dir = os.path.join(train_dir, label)
#     for image_file in os.listdir(label_dir):
#         image_path = os.path.join(label_dir, image_file)
#         image = cv2.imread(image_path)
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         data.append(image)
#         labels.append(label)

# # 데이터를 NumPy 배열로 변환
# data = np.array(data)
# labels = np.array(labels)

# # 클래스 레이블 인코딩
# le = LabelEncoder()
# labels_encoded = le.fit_transform(labels)

# # 데이터 섞기
# data_shuffled, labels_shuffled = shuffle(data, labels_encoded, random_state=42)

# # 훈련 데이터와 검증 데이터로 분할
# train_data, val_data, train_labels, val_labels = train_test_split(data_shuffled, labels_shuffled, test_size=0.2, random_state=42)

# # DeepFace 모델 사용
# for i in range(len(val_data)):
#     image = val_data[i]
#     label = class_labels[val_labels[i]]

#     # DeepFace 모델 사용
#     result = DeepFace.analyze(image, enforce_detection=False)  # Set enforce_detection to False

#     # 결과 출력
#     print("Emotion: ", result[0]['emotion'])
#     print("Age: ", result[0]['age'])
#     print("Gender: ", result[0]['gender'])
#     # 여러 다른 정보들도 포함되어 있습니다.

#     # 이미지에 레이블 붙이기
#     label = f"Age: {result[0]['age']}, Gender: {result[0]['gender']}, Emotion: {result[0]['emotion']}"
#     cv2.putText(image, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

#     # 결과 이미지 표시
#     display(Image(image))

# %%
# from deepface import DeepFace
# import cv2
# from IPython.display import Image, display

# # 선택한 테스트 이미지 경로
# test_image_path = '/content/drive/MyDrive/images/nj5.png'

# # 테스트 이미지 로드
# test_image = cv2.imread(test_image_path)
# test_image_rgb = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

# # DeepFace 모델 사용
# result = DeepFace.analyze(test_image_rgb, enforce_detection=False)  # Set enforce_detection to False

# # 결과 출력
# print("Emotion: ", result[0]['emotion'])
# print("Age: ", result[0]['age'])
# print("Gender: ", result[0]['gender'])
# # 여러 다른 정보들도 포함되어 있습니다.

# # 이미지에 레이블 붙이기
# label = f"Age: {result[0]['age']}, Gender: {result[0]['gender']}, Emotion: {result[0]['emotion']}"
# cv2.putText(test_image, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# # 결과 이미지 저장
# result_image_path = '/content/drive/MyDrive/images/result_image_test.jpg'
# cv2.imwrite(result_image_path, test_image)

# # 결과 이미지 표시
# display(Image(filename=result_image_path))

# %% [markdown]
# # **파일 변환**

# %%
# !pip install skl2onnx
# !pip install onnx2keras
# !pip install onnx-tf
# !pip install tf2onnx
# !pip install onnx2tf
# !pip install onnx-graphsurgeon
# !pip install tensorflow onnx

# %%
# !pip install git+https://github.com/onnx/onnx-tensorflow.git
# !pip install git+https://github.com/onnx/onnx-graphsurgeon.git

# %%
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType
import pickle

# Load the trained KNN classifier
model_path = '/content/drive/MyDrive/Openvino_SmartGalleryTeamProject/trained_knn_model.clf'
with open(model_path, 'rb') as f:
    knn_clf = pickle.load(f)

# Convert the scikit-learn model to ONNX format
initial_type = [('float_input', FloatTensorType([None, len(knn_clf.classes_)]))]
onnx_model = convert_sklearn(knn_clf, initial_types=initial_type)

# Save the ONNX model to a file
onnx_path = '/content/drive/MyDrive/Openvino_SmartGalleryTeamProject/trained_knn_model.onnx'
with open(onnx_path, 'wb') as f:
    f.write(onnx_model.SerializeToString())

print(f"ONNX model saved to: {onnx_path}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-117f06cbb074> in <cell line: 1>()
# ----> 1 from skl2onnx import convert_sklearn
#       2 from skl2onnx.common.data_types import FloatTensorType
#       3 import pickle
#       4
#       5 # Load the trained KNN classifier
#
# ModuleNotFoundError: No module named 'skl2onnx'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !python -m tf2onnx.convert --opset 12 --tflite --saved-model /content/drive/MyDrive/Openvino_SmartGalleryTeamProject/trained_knn_model.onnx --output /content/drive/MyDrive/Openvino_SmartGalleryTeamProject/knn_fr_model.tflite

# %%
import onnx
from onnx_tf.backend import prepare
import tf2onnx
import tensorflow as tf

# Load the ONNX model
onnx_model_path = '/content/drive/MyDrive/Openvino_SmartGalleryTeamProject/trained_knn_model.onnx'
onnx_model = onnx.load(onnx_model_path)

# Convert ONNX model to TensorFlow representation
tf_rep = prepare(onnx_model)

# Save the TensorFlow SavedModel
saved_model_dir = '/content/drive/MyDrive/Openvino_SmartGalleryTeamProject/knn_saved_model'

with tf.compat.v1.Session() as sess:
    # Convert ONNX model to TensorFlow graph
    g = tf2onnx.tfonnx.process_tf_graph(tf_rep.graph)
    tf.compat.v1.graph_util.import_graph_def(g.as_graph_def(), name='')
    tf.saved_model.save(sess, saved_model_dir)
